# %% [markdown]
# <a href="https://colab.research.google.com/github/sathizz7/MongoDB-Project/blob/main/Analysis_mongodb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "pymongo[srv]"

# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://yashwanth:2000yashwanth@cluster0.kyl08ia.mongodb.net/?retryWrites=true&w=majority")

# %%
client.list_database_names()
# Out:
# ['Guvi',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_guides',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'testing',
#  'admin',
#  'local']

# %%
db = client['testing']

# %%
db.list_collection_names()
# Out:
# ['listingsAndReviews']

# %%
db = client["Guvi"]

# %%
my_collection = db['session']

# %%
my_collection.insert_one({"name" : "yashwanth", "age": 22, "location": "Mysore"})

# %%
data = [{"name" : "rahul", "age": 23, "location": "Mysore","_id":20},{"name" : "suman", "age": 25, "location": "Mysore","_id":30},
        {"_id":40,"name" : "kundan", "age": 24, "location": "kolkata"},
        {"_id":50,"name" : "sachin", "age": 25, "location": "Mysore"}]

# %%
my_collection.insert_many(data)

# %%
my_collection.find_one()
# Out:
# {'_id': ObjectId('6378d42c004bb267da3d4a63'),
#  'name': 'yashwanth',
#  'age': 22,
#  'location': 'Mysore'}

# %%
for i in my_collection.find():
    print(i)
# Out:
# {'_id': ObjectId('6378d42c004bb267da3d4a63'), 'name': 'yashwanth', 'age': 22, 'location': 'Mysore'}
# {'_id': ObjectId('6378d525004bb267da3d4a64'), 'name': 'rahul', 'age': 23, 'location': 'Mysore'}
# {'_id': ObjectId('6378d525004bb267da3d4a65'), 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': ObjectId('6378d525004bb267da3d4a66'), 'name': 'sachin', 'age': 25, 'location': 'Mysore'}
# {'_id': 1, 'name': 'rahul', 'age': 23, 'location': 'Mysore'}
# {'_id': 2, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 3, 'name': 'sachin', 'age': 25, 'location': 'Mysore'}
# {'_id': 20, 'name': 'rahul', 'age': 23, 'location': 'Mysore'}
# {'_id': 30, 'name': 'suman', 'age': 25, 'location': 'Mysore'}
# {'_id': 40, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 50, 'name': 'sachin', 'age': 25, 'location': 'Mysore'}

# %%
for i in my_collection.find({"age":24}):
    print(i)
# Out:
# {'_id': ObjectId('6378d525004bb267da3d4a65'), 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 2, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 40, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}

# %%
for i in my_collection.find({"age": 24},{"_id":0,"name":1}):
    print(i)
# Out:
# {'name': 'kundan'}
# {'name': 'kundan'}
# {'name': 'kundan'}

# %%
for i in my_collection.find({"age": 24},{"_id":0,"name":1,"location": 1}):
    print(i)
# Out:
# {'name': 'kundan', 'location': 'kolkata'}
# {'name': 'kundan', 'location': 'kolkata'}
# {'name': 'kundan', 'location': 'kolkata'}

# %%
for i in my_collection.find({"age":{"$gte":24}}):
    print(i)
# Out:
# {'_id': ObjectId('6378d525004bb267da3d4a65'), 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': ObjectId('6378d525004bb267da3d4a66'), 'name': 'sachin', 'age': 25, 'location': 'Mysore'}
# {'_id': 2, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 3, 'name': 'sachin', 'age': 25, 'location': 'Mysore'}
# {'_id': 30, 'name': 'suman', 'age': 25, 'location': 'Mysore'}
# {'_id': 40, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 50, 'name': 'sachin', 'age': 25, 'location': 'Mysore'}

# %%
for i in my_collection.find({"$or":[{"age":{"$gte":24}},{"location": "kolkata"}]}):
    print(i)
# Out:
# {'_id': ObjectId('6378d525004bb267da3d4a65'), 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': ObjectId('6378d525004bb267da3d4a66'), 'name': 'sachin', 'age': 25, 'location': 'Mysore'}
# {'_id': 2, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 3, 'name': 'sachin', 'age': 25, 'location': 'Mysore'}
# {'_id': 30, 'name': 'suman', 'age': 25, 'location': 'Mysore'}
# {'_id': 40, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 50, 'name': 'sachin', 'age': 25, 'location': 'Mysore'}

# %%
for i in my_collection.find():
    print(i)
# Out:
# {'_id': ObjectId('6378d42c004bb267da3d4a63'), 'name': 'yashwanth', 'age': 22, 'location': 'Mysore'}
# {'_id': ObjectId('6378d525004bb267da3d4a64'), 'name': 'rahul', 'age': 23, 'location': 'Mysore'}
# {'_id': ObjectId('6378d525004bb267da3d4a65'), 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': ObjectId('6378d525004bb267da3d4a66'), 'name': 'sachin', 'age': 25, 'location': 'delhi'}
# {'_id': 1, 'name': 'rahul', 'age': 23, 'location': 'Mysore'}
# {'_id': 2, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 3, 'name': 'sachin', 'age': 25, 'location': 'delhi'}
# {'_id': 20, 'name': 'rahul', 'age': 23, 'location': 'Mysore'}
# {'_id': 30, 'name': 'suman', 'age': 25, 'location': 'Mysore'}
# {'_id': 40, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 50, 'name': 'sachin', 'age': 25, 'location': 'delhi'}

# %%
Q = {"name":"sachin"}
New = {"$set":{"location": "delhi"}}

# %%
my_collection.update_one(Q,New)

# %%
for i in my_collection.find({"name" : "sachin"}):
    print(i)
# Out:
# {'_id': ObjectId('6378d525004bb267da3d4a66'), 'name': 'sachin', 'age': 25, 'location': 'delhi'}
# {'_id': 3, 'name': 'sachin', 'age': 25, 'location': 'delhi'}
# {'_id': 50, 'name': 'sachin', 'age': 25, 'location': 'delhi'}

# %%
my_collection.update_many(Q,New)

# %%
Q = {"location" : "Mysore"}
New = {"$set":{"age": 30}}

# %%
my_collection.update_many(Q,New)

# %%
for i in my_collection.find():
    print(i)
# Out:
# {'_id': ObjectId('6378d42c004bb267da3d4a63'), 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': ObjectId('6378d525004bb267da3d4a64'), 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': ObjectId('6378d525004bb267da3d4a65'), 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': ObjectId('6378d525004bb267da3d4a66'), 'name': 'sachin', 'age': 25, 'location': 'delhi'}
# {'_id': 1, 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': 2, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 3, 'name': 'sachin', 'age': 25, 'location': 'delhi'}
# {'_id': 20, 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': 30, 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': 40, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 50, 'name': 'sachin', 'age': 25, 'location': 'delhi'}

# %%
my_collection.delete_one({"name":"sachin"})

# %%
for i in my_collection.find():
    print(i)
# Out:
# {'_id': ObjectId('6378d42c004bb267da3d4a63'), 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': ObjectId('6378d525004bb267da3d4a64'), 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': ObjectId('6378d525004bb267da3d4a65'), 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 1, 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': 2, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 3, 'name': 'sachin', 'age': 25, 'location': 'delhi'}
# {'_id': 20, 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': 30, 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': 40, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 50, 'name': 'sachin', 'age': 25, 'location': 'delhi'}

# %%
my_collection.delete_many({"name":"sachin"})

# %%
for i in my_collection.find():
    print(i)
# Out:
# {'_id': ObjectId('6378d42c004bb267da3d4a63'), 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': ObjectId('6378d525004bb267da3d4a64'), 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': ObjectId('6378d525004bb267da3d4a65'), 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 1, 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': 2, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}
# {'_id': 20, 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': 30, 'name': 'canelo', 'age': 30, 'location': 'Mysore'}
# {'_id': 40, 'name': 'kundan', 'age': 24, 'location': 'kolkata'}

# %%
my_collection = db['supermart']

# %%
my_collection.find_one()
# Out:
# {'_id': ObjectId('6378e8b56ce6995855202a7f'),
#  'Order ID': 'OD1',
#  'Customer Name': 'Harish',
#  'Category': 'Oil & Masala',
#  'Sub Category': 'Masalas',
#  'City': 'Vellore',
#  'Region': 'North',
#  'Sales': 1254,
#  'Discount': 0.12,
#  'Profit': 401.28,
#  'State': 'Tamil Nadu'}

# %%
for i in my_collection.find():
    print(i)
# Out:
# {'_id': ObjectId('6378e8b56ce6995855202a7f'), 'Order ID': 'OD1', 'Customer Name': 'Harish', 'Category': 'Oil & Masala', 'Sub Category': 'Masalas', 'City': 'Vellore', 'Region': 'North', 'Sales': 1254, 'Discount': 0.12, 'Profit': 401.28, 'State': 'Tamil Nadu'}
# {'_id': ObjectId('6378e8b56ce6995855202a80'), 'Order ID': 'OD2', 'Customer Name': 'Sudha', 'Category': 'Beverages', 'Sub Category': 'Health Drinks', 'City': 'Krishnagiri', 'Region': 'South', 'Sales': 749, 'Discount': 0.18, 'Profit': 149.8, 'State': 'Tamil Nadu'}
# {'_id': ObjectId('6378e8b56ce6995855202a81'), 'Order ID': 'OD3', 'Customer Name': 'Hussain', 'Category': 'Food Grains', 'Sub Category': 'Atta & Flour', 'City': 'Perambalur', 'Region': 'West', 'Sales': 2360, 'Discount': 0.21, 'Profit': 165.2, 'State': 'Tamil Nadu'}
# ...

# %%
for i in my_collection.find({'City' : "Chennai"},{"_id":0,"Customer Name":1}.sort('profit',-1).limit(3)):  
    print(i)
# Out:
# {'Customer Name': 'Krithika'}
# {'Customer Name': 'Jonas'}
# {'Customer Name': 'Mathew'}
# {'Customer Name': 'Veena'}
# {'Customer Name': 'Krithika'}
# {'Customer Name': 'Akash'}
# {'Customer Name': 'Shah'}
# {'Customer Name': 'Amrish'}
# {'Customer Name': 'Muneer'}
# {'Customer Name': 'Amy'}
# {'Customer Name': 'Sundar'}
# {'Customer Name': 'Sheeba'}
# {'Customer Name': 'Jonas'}
# {'Customer Name': 'Malik'}
# {'Customer Name': 'Hussain'}
# {'Customer Name': 'Malik'}
# {'Customer Name': 'Rumaiza'}
# {'Customer Name': 'Malik'}
# {'Customer Name': 'Amrish'}
# {'Customer Name': 'Sundar'}
# {'Customer Name': 'Willams'}
# {'Customer Name': 'Shah'}
# {'Customer Name': 'Haseena'}
# {'Customer Name': 'Jackson'}
# {'Customer Name': 'Komal'}
# {'Customer Name': 'Yusuf'}
# {'Customer Name': 'Sharon'}
# {'Customer Name': 'Shree'}
# {'Customer Name': 'Veena'}
# {'Customer Name': 'Adavan'}
# {'Customer Name': 'Muneer'}
# {'Customer Name': 'Verma'}
# {'Customer Name': 'Sudha'}
# ...

# %%
q = {"City":"Vellore"}
p = {'Sub Category':1,"Profit":1,"_id":0}

# %%
for i in my_collection.find(q,p).sort("Profit",-1).limit(3):
    print(i)
# Out:
# {'Sub Category': 'Masalas', 'Profit': 1040.85}
# {'Sub Category': 'Organic Staples', 'Profit': 1024.38}
# {'Sub Category': 'Breads & Buns', 'Profit': 1017.72}

# %%
q = {"$and":[{"$or":[{"City":"Vellore"},{"City":"Chennai"}]},{"Category": "Oil & Masala"},{"Sales":{"$lt":1000}}]}

# %%
for i in my_collection.find(q).sort("Customer Name",1).sort("Sales",-1):
    print(i)
# Out:
# {'_id': ObjectId('6378e8c06ce6995855204a51'), 'Order ID': 'OD8147', 'Customer Name': 'Shah', 'Category': 'Oil & Masala', 'Sub Category': 'Spices', 'City': 'Chennai', 'Region': 'East', 'Sales': 993, 'Discount': 0.29, 'Profit': 436.92, 'State': 'Tamil Nadu'}
# {'_id': ObjectId('6378e8bf6ce69958552045a5'), 'Order ID': 'OD6951', 'Customer Name': 'Sundar', 'Category': 'Oil & Masala', 'Sub Category': 'Masalas', 'City': 'Vellore', 'Region': 'Central', 'Sales': 926, 'Discount': 0.14, 'Profit': 157.42, 'State': 'Tamil Nadu'}
# {'_id': ObjectId('6378e8bf6ce6995855204684'), 'Order ID': 'OD7174', 'Customer Name': 'Verma', 'Category': 'Oil & Masala', 'Sub Category': 'Spices', 'City': 'Vellore', 'Region': 'East', 'Sales': 917, 'Discount': 0.27, 'Profit': 339.29, 'State': 'Tamil Nadu'}
# ...

# %%
import json

# %%
file = open("Supermart.json","r")

# %%
for i in file:
    print(i)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(file)
# Out:
# <_io.TextIOWrapper name='Sample.json' mode='r' encoding='cp1252'>

# %%
c =0 

for i in file:
    if c<=5:
        print(i)
    else:
        break
    c=c+1
# Out:
# [{"Name":"Aravind","Age":25,"Salary":25000,"Company":"Amazon","Gender":"Male","Department":"Data_Science","Branch":"Chennai"},
#
# {"Name":"Arun","Age":45,"Salary":50000,"Company":"Google","Gender":"Male","Department":"Administraion","Branch":"Bangalore"},
#
# {"Name":"Suresh","Age":30,"Salary":34000,"Company":"Google","Gender":"Male","Department":"Quality","Branch":"Chennai"},
#
# {"Name":"Ramesh","Age":33,"Salary":38000,"Company":"Amazon","Gender":"Male","Department":"FSD","Branch":"Delhi"},
#
# {"Name":"Kannan","Age":45,"Salary":40000,"Company":"Amazon","Gender":"Male","Department":"Quality","Branch":"Chennai"},
#
# {"Name":"Azar","Age":23,"Salary":22000,"Company":"Amazon","Gender":"Male","Department":"Administraion","Branch":"Chennai"},

# %%
new = db["yash"]

# %%
client.list_database_names()
# Out:
# ['Guvi',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_guides',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'testing',
#  'admin',
#  'local']

# %%
db.list_collection_names()
# Out:
# ['session', 'supermart']

# %%
for i in file:
    x = json.loads(i)
    new.insert_one(x)

# %%
y = json.loads(file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [138], line 1
# ----> 1 y = json.loads(file)
#
# File C:\Python10.7\lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not TextIOWrapper

# %%
x = [json.loads(y) for y in open("Supermart.json","r",encoding="utf-8")]
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In [126], line 1
# ----> 1 x = [json.loads(y) for y in open("Supermart.json","r",encoding="utf-8")]
#
# Cell In [126], line 1, in <listcomp>(.0)
# ----> 1 x = [json.loads(y) for y in open("Supermart.json","r",encoding="utf-8")]
#
# File C:\Python10.7\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File C:\Python10.7\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
# ...
